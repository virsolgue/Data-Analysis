# %% [markdown]
# <a href="https://colab.research.google.com/github/virsolgue/Data-Analysis/blob/main/Taller%20II%20-%20Big%20Data%20y%20Salud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import csv
import pandas as pd
from statistics import mean

COLUMNS_IN_ANALYSIS = [2,3,8]

#Carga del dataset original
with open ('./ejemplo real.csv', newline= '') as f:
	reader = csv.reader(f, delimiter=';')
	data_set = list(reader)

#Se arma además un Data Frame de Pandas:
data_frame = pd.read_csv('./ejemplo real.csv', delimiter = ';')
attribute_name = data_frame.columns

#Column description:
#  0  -  person_uid
#  1  -  Performed_at_Date
#  2  -  GenderId
#  3  -  Gender
#  4  -  Duration_Id
#  5  -  Duration
#  6  -  Frequency_Id
#  7  -  Frequency
#  8  -  Classification_Pain_Id
#  9  -  Classification_Pain
#  10  -  Surveyed_Date
#  11  -  SurveyID
#  12  -  Survey
#  13  -  _Orden
#  14  -  Oswestry01 Group Id
#  15  -  Oswestry01 Group
#  16  -  Oswestry01
#  17  -  Oswestry02 Group Id
#  18  -  Oswestry02 Group
#  19  -  Oswestry02
#  20  -  Oswestry03 Group Id
#  21  -  Oswestry03 Group
#  22  -  Oswestry03
#  23  -  Age
#  24  -  Age Range Id
#  25  -  Age Range
#  26  -  Weight
#  27  -  Height
#  28  -  Bmi
#  29  -  BMI Group Id
#  30  -  BMI Group
#  31  -  Test # TxT
#  32  -  Test #
#  33  -  Test_QTY
#  34  -  Measure_Absolute
#  35  -  Measure Type
#  36  -  Movement Category
#  37  -  Movement_Type
#  38  -  Movement SubCategory

#Exploración del tipo de dato y algunas métricas estadísticas:
print("Los tipos de datos de las variables son:")
print("-------------------------------------------------------------------------------------")
print(data_frame.dtypes)
print()
print("Estadísticas de las variables:")
print("-------------------------------------------------------------------------------------")
for i in COLUMNS_IN_ANALYSIS:
  print (attribute_name[i], ": ")
  print (data_frame[attribute_name[i]].describe())
  print()
# Out:
# Los tipos de datos de las variables son:
# -------------------------------------------------------------------------------------
# person_uid                 object
# Performed_at_Date          object
# GenderId                    int64
# Gender                     object
# Duration_Id               float64
# Duration                   object
# Frequency_Id              float64
# Frequency                  object
# Classification_Pain_Id    float64
# Classification_Pain        object
# Surveyed_Date              object
# SurveyID                  float64
# Survey                     object
# _Orden                      int64
# Oswestry01 Group Id       float64
# Oswestry01 Group           object
# Oswestry01                float64
# Oswestry02 Group Id       float64
# Oswestry02 Group           object
# Oswestry02                float64
# Oswestry03 Group Id       float64
# Oswestry03 Group           object
# Oswestry03                float64
# Age                         int64
# Age Range Id                int64
# Age Range                  object
# Weight                    float64
# Height                    float64
# Bmi                       float64
# BMI Group Id                int64
# BMI Group                  object
# Test # TxT                 object
# Test #                      int64
# Test_QTY                    int64
# Measure_Absolute          float64
# Measure Type               object
# Movement Category          object
# Movement_Type              object
# Movement SubCategory       object
# dtype: object
#
# Estadísticas de las variables:
# -------------------------------------------------------------------------------------
# GenderId :
# count    43781.000000
# mean         1.473973
# std          0.499328
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          2.000000
# Name: GenderId, dtype: float64
#
# Gender :
# count      43781
# unique         2
# top       female
# freq       23030
# Name: Gender, dtype: object
#
# Classification_Pain_Id :
# count    9094.000000
# mean        1.779855
# std         1.045078
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         6.000000
# Name: Classification_Pain_Id, dtype: float64
# <ipython-input-8-7644144c343e>:14: DtypeWarning: Columns (5,7,9,10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = pd.read_csv('./ejemplo real.csv', delimiter = ';')
